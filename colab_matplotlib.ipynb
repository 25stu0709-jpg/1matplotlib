# %% [markdown]
# <a href="https://colab.research.google.com/github/25stu0709-jpg/1matplotlib/blob/main/colab_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1matplotlib 맛보

# %%
import numpy as np
import matplotlib.pyplot as plt

# t 값 생성
t = np.linspace(0, 2 * np.pi, 1000)

# 하트 모양의 x, y 좌표 공식
x = 16 * np.sin(t)**3
y = 13 * np.cos(t) - 5 * np.cos(2*t) - 2 * np.cos(3*t) - np.cos(4*t)

# 그래프 그리기
plt.figure(figsize=(6,6))
plt.plot(x, y, color='red')
plt.fill_between(x, y, color='pink')
plt.title("Heart Shape with Matplotlib")
plt.axis('off')  # 축 숨기기
plt.show()
